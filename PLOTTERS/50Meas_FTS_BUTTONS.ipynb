# %% [markdown]
# # SIMA320 MCDU "L"

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define the folder containing the CSV files
folder_path = "/home/rluser/thesis_ws/src/TestData_samples/Variance_MCDU_L_SIMA320"
#folder_path = "/home/rluser/thesis_ws/src/TestData_samples/var_MCDU_L_5_GRIPA"

# Initialize lists to store extracted features
force_z_values = []
pose_z_values = []

# Iterate over each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):
        # Read the CSV file
        file_path = os.path.join(folder_path, filename)
        df = pd.read_csv(file_path)
        
        # Extract relevant columns
        force_z_values.append(df['Force_Z'].values)
        pose_z_values.append(df['Pose_Z'].values)

# # Plotting
# plt.figure(figsize=(12, 3))
# for force_z in force_z_values:
#     plt.plot(force_z, label='Force_Z')

# # 5N on button L of MCDU SIMA

# plt.title('MCDU "L" Button with 5N: 50 measurements')
# plt.xlabel('Samples at 500Hz [2ms]')
# plt.ylabel('TCP Force Z [N]')
# plt.grid(True)

#force_z_values = pose_z_values
rows = len(force_z_values)
cols = len(force_z_values[0])

maxv, minv = [], []
i=0
for i in range(cols):
    max_val, min_val = float('-inf'), float('inf')
    for j in range(rows):
        val = force_z_values[j][i]
        if val > max_val:
            max_val = val
        if val < min_val:
            min_val = val
    maxv.append(max_val)
    minv.append(min_val)

diff = []
for i, (a, b) in enumerate(zip(minv, maxv)):
    diff.append(b - a)

plt.figure(figsize=(10, 8))

plt.subplot(3,1,1)
for force_z in force_z_values:
    plt.plot(force_z, label='Force_Z')
plt.title('50 measurements, Button pressing (Fz = 5N)', fontsize=16)
#plt.xlabel('Samples at 500Hz [2ms]')
plt.ylabel('TCP Force Z [N]')
#plt.legend()
plt.grid(True)

plt.subplot(3, 1, 2)  # 2 rows, 1 column, subplot 1
plt.plot(maxv, label='Max')
plt.plot(minv, label='Min')
plt.ylabel("[N]")
plt.grid(True)
plt.legend()

plt.subplot(3, 1, 3)  # 2 rows, 1 column, subplot 2
plt.plot(diff, label='Difference')
plt.ylabel("[N]")
plt.xlabel("Samples at 500Hz [2ms]")
plt.grid(True)
plt.legend()

plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define the folder containing the CSV files
folder_path = "/home/rluser/thesis_ws/src/TestData_samples/Variance_MCDU_L_SIMA320"
#folder_path = "/home/rluser/thesis_ws/src/TestData_samples/var_MCDU_L_5_GRIPA"

# Initialize lists to store extracted features
force_z_values = []
pose_z_values = []

# Iterate over each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):
        # Read the CSV file
        file_path = os.path.join(folder_path, filename)
        df = pd.read_csv(file_path)
        
        # Extract relevant columns
        force_z_values.append(df['Force_Z'].values)
        pose_z_values.append(df['Pose_Z'].values)

rows = len(force_z_values)
cols = len(force_z_values[0])

maxv, minv = [], []
i=0
for i in range(cols):
    max_val, min_val = float('-inf'), float('inf')
    for j in range(rows):
        val = force_z_values[j][i]
        if val > max_val:
            max_val = val
        if val < min_val:
            min_val = val
    maxv.append(max_val)
    minv.append(min_val)

diff = []
for i, (a, b) in enumerate(zip(minv, maxv)):
    diff.append(b - a)

# Calculate the mean and standard deviation for each time step
mean_values = np.mean(force_z_values, axis=0)
std_values = np.std(force_z_values, axis=0)

plt.figure(figsize=(12, 8))

plt.subplot(4,1,1)
for force_z in force_z_values:
    plt.plot(force_z, color='black', alpha=0.3)  # Plot in black with transparency
plt.title('50 measurements, Button pressing (Fz = 5N)', fontsize=16)
plt.ylabel('[N]')
plt.grid(True)

plt.subplot(4, 1, 2)
plt.plot(mean_values, color='black', label='Mean')
plt.fill_between(range(len(mean_values)), mean_values - std_values, mean_values + std_values, color='gray', alpha=0.5, label='Std Dev')
plt.ylabel("[N]")
plt.grid(True)
plt.legend()

plt.subplot(4, 1, 3)
plt.plot(maxv, color='black', label='Max')
plt.plot(minv, color='gray', label='Min')
plt.ylabel("[N]")
plt.grid(True)
plt.legend()

plt.subplot(4, 1, 4)
plt.plot(diff, color='black', label='Difference')
plt.ylabel("[N]")
plt.xlabel("Samples at 500Hz [2ms]")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define the folder containing the CSV files
folder_path = "/home/rluser/thesis_ws/src/TestData_samples/Variance_MCDU_L_SIMA320"
#folder_path = "/home/rluser/thesis_ws/src/TestData_samples/var_MCDU_L_5_GRIPA"

# Initialize lists to store extracted features
force_z_values = []
pose_z_values = []

# Iterate over each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):
        # Read the CSV file
        file_path = os.path.join(folder_path, filename)
        df = pd.read_csv(file_path)
        
        # Extract relevant columns
        force_z_values.append(df['Force_Z'].values)
        pose_z_values.append(df['Pose_Z'].values)

rows = len(force_z_values)
cols = len(force_z_values[0])

maxv, minv = [], []
i=0
for i in range(cols):
    max_val, min_val = float('-inf'), float('inf')
    for j in range(rows):
        val = force_z_values[j][i]
        if val > max_val:
            max_val = val
        if val < min_val:
            min_val = val
    maxv.append(max_val)
    minv.append(min_val)

diff = []
for i, (a, b) in enumerate(zip(minv, maxv)):
    diff.append(b - a)

# Calculate the mean and standard deviation for each time step
mean_values = np.mean(force_z_values, axis=0)
std_values = np.std(force_z_values, axis=0)

plt.figure(figsize=(12, 8))

start = 231
length = 500
end = start + length
color_r = 'grey'

plt.subplot(4,1,1)
for force_z in force_z_values:
    plt.plot(force_z, color='black', alpha=0.3)  # Plot in black with transparency
plt.axvspan(start, end, color=color_r, alpha=0.3)  # Highlight the rectangle area
plt.title('50 measurements, Button pressing (Fz = 5N)', fontsize=16)
plt.ylabel('[N]')
plt.grid(True)

plt.subplot(4, 1, 2)
plt.plot(mean_values, color='black', label='Mean')
plt.fill_between(range(len(mean_values)), mean_values - std_values, mean_values + std_values, color='gray', alpha=0.5, label='Std Dev')
plt.axvspan(start, end, color=color_r, alpha=0.3)  # Highlight the rectangle area
plt.ylabel("[N]")
plt.grid(True)
plt.legend()

plt.subplot(4, 1, 3)
plt.plot(maxv, color='black', label='Max')
plt.plot(minv, color='gray', label='Min')
#plt.axvspan(start, end, color=color_r, alpha=0.3)  # Highlight the rectangle area
plt.ylabel("[N]")
plt.grid(True)
plt.legend()

plt.subplot(4, 1, 4)
plt.plot(diff, color='black', label='Difference')
#plt.axvspan(start, end, color=color_r, alpha=0.3)  # Highlight the rectangle area
plt.ylabel("[N]")
plt.xlabel("Samples at 500Hz [2ms]", fontsize=14)
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # POSE Z 50 MEAS

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define the folder containing the CSV files
folder_path = "/home/rluser/thesis_ws/src/TestData_samples/Variance_MCDU_L_SIMA320"
#folder_path = "/home/rluser/thesis_ws/src/TestData_samples/var_MCDU_L_5_GRIPA"

# Initialize lists to store extracted features
force_z_values = []
pose_z_values = []

# Iterate over each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):
        # Read the CSV file
        file_path = os.path.join(folder_path, filename)
        df = pd.read_csv(file_path)
        
        # Extract relevant columns
        force_z_values.append(df['Force_Z'].values)
        pose_z_values.append(df['Pose_Z'].values)

force_z_values = pose_z_values
rows = len(force_z_values)
cols = len(force_z_values[0])

maxv, minv = [], []
i=0
for i in range(cols):
    max_val, min_val = float('-inf'), float('inf')
    for j in range(rows):
        val = force_z_values[j][i]
        if val > max_val:
            max_val = val
        if val < min_val:
            min_val = val
    maxv.append(max_val)
    minv.append(min_val)

diff = []
for i, (a, b) in enumerate(zip(minv, maxv)):
    diff.append(b - a)

plt.figure(figsize=(10, 8))

plt.subplot(3,1,1)
for force_z in force_z_values:
    plt.plot(force_z, label='Force_Z')
plt.title('50 measurements, Button pressing :Delta Pose Z', fontsize=16)
#plt.xlabel('Samples at 500Hz [2ms]')
plt.ylabel('DeltaPose_Z [m]')
#plt.legend()
plt.grid(True)

plt.subplot(3, 1, 2)  # 2 rows, 1 column, subplot 1
plt.plot(maxv, label='Max')
plt.plot(minv, label='Min')
plt.ylabel("DeltaPose_Z [m]")
plt.grid(True)
plt.legend()

plt.subplot(3, 1, 3)  # 2 rows, 1 column, subplot 2
plt.plot(diff, label='Difference')
plt.ylabel("[m]")
plt.xlabel("Samples at 500Hz [2ms]")
plt.grid(True)
plt.legend()

plt.show()

# %%
measurements = [value for sublist in force_z_values for value in sublist]

# Calculate mean, standard deviation, and range
mean_force = np.mean(measurements)
std_deviation = np.std(measurements)
min_force = np.min(measurements)
max_force = np.max(measurements)
force_range = max_force - min_force

# Evaluate precision as the standard deviation
precision = std_deviation

# Evaluate errors as the difference between the mean force and the target force
error = abs(mean_force - 5)

print("Mean Force       : {:.4f} [N]".format(mean_force))
print("Precision (STD)  : {:.4f} [N]".format(std_deviation))
print("Min Force        : {:.4f} [N]".format(min_force))
print("Max Force        : {:.4f} [N]".format(max_force))
print("Range            : {:.4f} [N]".format(force_range))
print("Error            : {:.4f} [N]".format(error))



print("---- DO EVERYTHING AGAIN BUT WITH SLICED SIGNAL ----")
force_z_values = [sublist[400:] for sublist in force_z_values]
measurements = [value for sublist in force_z_values for value in sublist]

# Calculate mean, standard deviation, and range
mean_force = np.mean(measurements)
std_deviation = np.std(measurements)
min_force = np.min(measurements)
max_force = np.max(measurements)
force_range = max_force - min_force

# Evaluate precision as the standard deviation
precision = std_deviation

# Evaluate errors as the difference between the mean force and the target force
error = abs(mean_force - 5)

print("Mean Force       : {:.4f} [N]".format(mean_force))
print("Precision (STD)  : {:.4f} [N]".format(std_deviation))
print("Min Force        : {:.4f} [N]".format(min_force))
print("Max Force        : {:.4f} [N]".format(max_force))
print("Range            : {:.4f} [N]".format(force_range))
print("Error            : {:.4f} [N]".format(error))
# Out:
# Mean Force       : 3.4601 [N]
# Precision (STD)  : 2.9099 [N]
# Min Force        : -0.7029 [N]
# Max Force        : 8.7371 [N]
# Range            : 9.4400 [N]
# Error            : 1.5399 [N]
# ---- DO EVERYTHING AGAIN BUT WITH SLICED SIGNAL ----
# Mean Force       : 4.8684 [N]
# Precision (STD)  : 2.2141 [N]
# Min Force        : -0.4094 [N]
# Max Force        : 8.7371 [N]
# Range            : 9.1466 [N]
# Error            : 0.1316 [N]

# %% [markdown]
# ---- ORIGINAL SIGNAL (EVEN INITIAL PLATEAU) ----
#
# Mean Force       : 3.4601 [N]
# Precision (STD)  : 2.9099 [N]
# Min Force        : -0.7029 [N]
# Max Force        : 8.7371 [N]
# Range            : 9.4400 [N]
# Error            : 1.5399 [N]
#
# ---- DO EVERYTHING AGAIN BUT WITH SLICED SIGNAL ----
#
# Mean Force       : 4.8684 [N]
# Precision (STD)  : 2.2141 [N]
# Min Force        : -0.4094 [N]
# Max Force        : 8.7371 [N]
# Range            : 9.1466 [N]
# Error            : 0.1316 [N]

# %% [markdown]
# # NEW SIMULATOR, GRIPPER + FINGER

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define the folder containing the CSV files
folder_path = "/home/user/thesis_ws/src/TestData_samples/var_MCDU_L_5_GRIPA"

# Initialize lists to store extracted features
force_z_values = []
pose_z_values = []

# Iterate over each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):
        # Read the CSV file
        file_path = os.path.join(folder_path, filename)
        df = pd.read_csv(file_path)
        
        # Extract relevant columns
        force_z_values.append(df['Force_Z'].values)
        pose_z_values.append(df['Pose_Z'].values)

# Plotting
plt.figure(figsize=(10, 4))
for force_z in force_z_values:
    plt.plot(force_z, label='Force_Z')

# 5N on button L of MCDU SIMA

plt.title('MCDU "L" Button with 5N: 50 measurements')
plt.xlabel('Samples at 500Hz [2ms]')
plt.ylabel('TCP Force Z [N]')
#plt.legend()
plt.grid(True)

# %%
rows = len(force_z_values)
cols = len(force_z_values[0])

print("Number of rows:", rows)
print("Number of columns:", cols)

maxv, minv = [], []
i=0
for i in range(cols):
    max_val, min_val = float('-inf'), float('inf')
    for j in range(rows):
        val = force_z_values[j][i]
        if val > max_val:
            max_val = val
        if val < min_val:
            min_val = val
    maxv.append(max_val)
    minv.append(min_val)

diff = []
for i, (a, b) in enumerate(zip(minv, maxv)):
    diff.append(b - a)

plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)  # 2 rows, 1 column, subplot 1
plt.plot(maxv, label='Max')
plt.plot(minv, label='Min')
plt.ylabel("[N]")
plt.grid(True)
plt.legend()

plt.subplot(2, 1, 2)  # 2 rows, 1 column, subplot 2
plt.plot(diff, label='Difference')
plt.ylabel("[N]")
plt.xlabel("Samples at 500Hz [2ms]")
plt.grid(True)
plt.legend()

plt.show()
# Out:
# Number of rows: 50
# Number of columns: 1400

# %% [markdown]
# # OH RAIN BUTTON 8N

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define the folder containing the CSV files
folder_path = "/home/user/thesis_ws/src/TestData_samples/var_OH_RAIN_8_GRIPA"

# Initialize lists to store extracted features
force_z_values = []
pose_z_values = []

# Iterate over each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):
        # Read the CSV file
        file_path = os.path.join(folder_path, filename)
        df = pd.read_csv(file_path)
        
        # Extract relevant columns
        force_z_values.append(df['Force_Z'].values)
        pose_z_values.append(df['Pose_Z'].values)

# Plotting
plt.figure(figsize=(12, 6))
for force_z in force_z_values:
    plt.plot(force_z, label='Force_Z')

# 5N on button L of MCDU SIMA

plt.title('50 measurements, same test')
plt.xlabel('Samples [2ms]')
plt.ylabel('[N]')
#plt.legend()
plt.grid(True)
#plt.show()

rows = len(force_z_values)
cols = len(force_z_values[0])

print("Number of rows:", rows)
print("Number of columns:", cols)

maxv, minv = [], []
i=0
for i in range(cols):
    max_val, min_val = float('-inf'), float('inf')
    for j in range(rows):
        val = force_z_values[j][i]
        if val > max_val:
            max_val = val
        if val < min_val:
            min_val = val
    maxv.append(max_val)
    minv.append(min_val)

diff = []
for i, (a, b) in enumerate(zip(minv, maxv)):
    diff.append(b - a)

plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)  # 2 rows, 1 column, subplot 1
plt.plot(maxv, label='Max')
plt.plot(minv, label='Min')
plt.grid(True)
plt.legend()

plt.subplot(2, 1, 2)  # 2 rows, 1 column, subplot 2
plt.plot(diff, label='Difference')
plt.grid(True)
plt.legend()

plt.show()
# Out:
# Number of rows: 50
# Number of columns: 1400
